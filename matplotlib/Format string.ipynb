# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y,'g+-.')

# %%
plt.plot(x,y,'--r*') #order does not matter

# %%
plt.plot(x,y,'yD')

# %%
plt.plot(x,y,color='#923467',linewidth=5,alpha=0.2)
